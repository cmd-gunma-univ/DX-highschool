# %% [markdown]
# <a href="https://colab.research.google.com/github/cmd-gunma-univ/DX-highschool/blob/main/%E3%82%82%E3%81%AE%E3%81%A4%E3%81%8F%E3%82%8ADX3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ラズベリーパイの基本操作

# %% [markdown]
# ## ラズベリーパイへの接続
# ### ネットワークの基礎

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('yUGvJ_DbOdM', width=700, height=500)

# %% [markdown]
# ## Jupyterとは

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('vyxo07h90Rw', width=700, height=500)
