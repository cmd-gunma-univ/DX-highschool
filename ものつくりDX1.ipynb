# %% [markdown]
# <a href="https://colab.research.google.com/github/cmd-gunma-univ/DX-highschool/blob/main/%E3%82%82%E3%81%AE%E3%81%A4%E3%81%8F%E3%82%8ADX1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ものつくりDX ガイダンス
# 本授業のガイダンスとして，以下について説明しています。
# 詳細は動画を見てください。
# - **授業の目的**
#
#  ラズベリーパイを使って
#  - デジタル制御を理解する
#  - 機械学習の基礎を理解する
# - **ゴール**
#  - オリジナル作品の製作
#  - 「すうりDX」への活用

# %% [markdown]
# ## 概要

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ujE1IxsauLg', width=700, height=500)

# %% [markdown]
# ## ラズベリーパイとは

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('64Mvu13WXzg', width=700, height=500)

# %% [markdown]
# ## デジタルと機械学習

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('AKUw_iP-DKI', width=700, height=500)
