# %% [markdown]
# <a href="https://colab.research.google.com/github/cmd-gunma-univ/DX-highschool/blob/main/%E3%82%82%E3%81%AE%E3%81%A4%E3%81%8F%E3%82%8ADX2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python基礎

# %% [markdown]
# ##Pythonはどのような言語か？

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('2yUv6vO7-N8', width=700, height=500)

# %% [markdown]
# ## Pythonを使う上で最低限知っておくべきこと
# ## (生成AI活用を前提として)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('YD1LySK9jbg', width=700, height=500)

# %% [markdown]
# - 日本語からPythonへの翻訳としてGeminiを使おう
# - バージョンの概念を持とう!
# - コードは半角で書くように。全角が使えるのは # の後，もしくは ' または " で挟まれた文字のみ
# - 日本語の「。」→ 改行
# - 日本語の段落分け → インデント(半角スペース4個のこと。4つという決まりはなく一貫性があれば良いが，[PEP8](https://pep8-ja.readthedocs.io/ja/latest/)では半角スペース4つを推奨)

# %% [markdown]
# ## 例
# 1から10までの足し算を行うコードを書きなさい。

# %% [markdown]
# ---
# # Pythonの基礎文法

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Nt7EBUiDun8', width=700, height=500)

# %% [markdown]
# ## 変数
# 次のコードの x に 10 を代入し、print() で出力してください。

# %%
# ここにコードを書く
x = ____
print(x)  # 期待する出力: 10

# %% [markdown]
# 次のコードを完成させ、score を 10 増やして print() で出力してください。

# %%
score = 50
# ここで score を 10 増やす
____
print(score)  # 期待する出力: 60

# %% [markdown]
# ## 条件文
# ユーザーが入力した数が偶数か奇数かを判定し、結果を出力するプログラムを作成してください。
#
# 期待する出力例:
# ```
# 数字を入力してください: 7
# 7は奇数です
# ```

# %% [markdown]
# elif を使って成績判定
#
# テストの点数を入力すると、以下の基準で成績を出力するプログラムを作成してください。
# 	•	90点以上 → A
# 	•	70点以上90点未満 → B
# 	•	50点以上70点未満 → C
# 	•	50点未満 → D
#
#   期待する出力例:
#
#   ```
# テストの点数を入力してください: 85
# 成績: B
#   ```

# %% [markdown]
# ## ループ文
# 1から10までの数を表示してください。

# %% [markdown]
# 1から100までの合計を計算してください。

# %% [markdown]
# 1から10までの偶数だけを表示してください。

# %% [markdown]
# # インデント
# 以下のコードは if 文のインデントが正しくありません。正しく修正してください。

# %%
x = 10
if x > 5:
print("xは5より大きい")
